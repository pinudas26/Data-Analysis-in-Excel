# %% [markdown]
# # Assignment 1 - Exploratory Data Analysis
#
# This notebook loads the provided Excel file and performs basic EDA.

# %%
import pandas as pd

# Load Excel file
file_path = '/mnt/data/Assignment1-Excel.xlsx'
df = pd.read_excel(file_path)
df.head()

# %%
# Basic info
df.info()

# %%
# Descriptive statistics
df.describe(include='all')
